# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("C:/Users/rozar/Documents/csv/travel-Rio de Janeiro.xlsx", index_col = 0)
df
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa              3545            3012             533
#    Angola                    21662           21606              56
#    Cape Green                 2407            2407               0
#    Nigeria                     238             233               5
# Others                        1900            1783             117
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year
# Place
#     South Africa             Africa    Africa  2006
# ...

# %%
df.head(50)

# %%
df1['Continent Code'] = df1.Continent.replace(to_replace
                                              = ["Asia", "America","Africa","Oceania","Europe"], value = [1,2,3,4,5])
df1
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa              3545            3012             533
#    Angola                    21662           21606              56
#    Cape Green                 2407            2407               0
#    Nigeria                     238             233               5
# Others                        1900            1783             117
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year  Continent Code
# Place
#     South Africa             Africa    Africa  2006               3
# ...

# %%
df1=df.copy()
df1.isnull().sum()
# Out:
# Total Tourists      0
# Tourist by Air      0
# Tourist by Sea      0
# Continent Region    0
# Continent           0
# Year                0
# dtype: int64

# %%
df1['Tourist by Sea'].isnull()
# Out:
# Place
#     South Africa      False
#    Angola             False
#    Cape Green         False
#    Nigeria            False
# Others                False
#                       ...
# Others                False
# Australia             False
#  New Zealand          False
# Others                False
# Unspecified places    False
# Name: Tourist by Sea, Length: 930, dtype: bool

# %%
df1
# Out:
#                 Total Tourists  Tourist by Air  Tourist by Sea  \
# Continent Code
# 3                         3545            3012             533
# 3                        21662           21606              56
# 3                         2407            2407               0
# 3                          238             233               5
# 3                         1900            1783             117
# ...                        ...             ...             ...
# 5                         1688            1649              39
# 4                        13148           12929             219
# 4                         1764            1734              30
# 4                           35              31               4
# 4                            7               7               0
#
#                Continent Region Continent  Year
# Continent Code
# 3                        Africa    Africa  2006
# 3                        Africa    Africa  2006
# ...

# %%
c=df1.corr()
c

# %%
sns.heatmap(c, annot = True, cmap = 'coolwarm', linewidth = 2)

# %%
sns.distplot(df1['Year'], bins = 16, kde = False)
# Out:
# C:\Users\rozar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year'>

# %%
sns.distplot(df1['Year'], bins = 16, kde = True, hist = False)

# %%
sns.displot((df1['Year']), bins = 8, kde = True)

# %%
sns.displot((df1['Continent']), bins = 8, kde = True)

# %%
sns.countplot(df1['Continent'], hue = df1['Year'], palette = ['g', 'grey'])
# Out:
# C:\Users\rozar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
sns.countplot(df1['Total Tourists'], hue = df1['Year'], palette = ['g', 'grey'])
# Out:
# C:\Users\rozar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Tourists', ylabel='count'>

# %%
sns.countplot(x = "Continent", data = df1, hue = "Year")
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
sns.countplot(x = "Total Tourists", data = df1, hue = "Tourist by Sea")

# %%
sns.countplot(df1['Continent'], hue = df1['Year'], dodge = False, palette = ['r', 'b'], saturation = 1.5)
# Out:
# C:\Users\rozar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
sns.barplot(x = df1['Tourist by Sea'],y= df1['Continent'])
# Out:
# <AxesSubplot:xlabel='Tourist by Sea', ylabel='Continent'>

# %%
sns.boxplot(y = df1['Tourist by Sea'], x = df1['Year'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Tourist by Sea'>

# %%
g=sns.pairplot(
    df1,
    x_vars=["Tourist by Air", "Tourist by Sea", "Total Tourists"],
    y_vars=["Year", "Year"],  markers=["o", "s","D"]
)

# %%
df1.index.is_unique
# Out:
# False

# %%
df1.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df1.loc[~df.index.duplicated(), :]
# Out:
#                   Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa            3545            3012             533
#    Angola                  21662           21606              56
#    Cape Green               2407            2407               0
#    Nigeria                   238             233               5
# Others                      1900            1783             117
# ...                          ...             ...             ...
# Reino Unido                83560           82837             723
# Romania                     2600            2590              10
# Serbia                      1573            1570               3
# Turkey                      2732            2729               3
# Ukraine                     3175            3163              12
#
#                  Continent Region Continent  Year
# Place
#     South Africa           Africa    Africa  2006
#    Angola                  Africa    Africa  2006
# ...

# %%
df1.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df1.drop_duplicates()
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa              3545            3012             533
#    Angola                    21662           21606              56
#    Cape Green                 2407            2407               0
#    Nigeria                     238             233               5
# Others                        1900            1783             117
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year
# Place
#     South Africa             Africa    Africa  2006
# ...

# %%
df1.drop_duplicates(subset=['Total Tourists','Tourist by Air'])
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa              3545            3012             533
#    Angola                    21662           21606              56
#    Cape Green                 2407            2407               0
#    Nigeria                     238             233               5
# Others                        1900            1783             117
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year
# Place
#     South Africa             Africa    Africa  2006
# ...

# %%
df1.drop_duplicates(subset=['Total Tourists','Continent'])
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#     South Africa              3545            3012             533
#    Angola                    21662           21606              56
#    Cape Green                 2407            2407               0
#    Nigeria                     238             233               5
# Others                        1900            1783             117
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year
# Place
#     South Africa             Africa    Africa  2006
# ...

# %%
du.index.is_unique
# Out:
# False

# %%
du.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
# ...

# %%
reset=df1.reset_index(level='Place')
reset
# Out:
#                   Place  Total Tourists  Tourist by Air  Tourist by Sea  \
# 0          South Africa            3545            3012             533
# 1                Angola           21662           21606              56
# 2            Cape Green            2407            2407               0
# 3               Nigeria             238             233               5
# 4                Others            1900            1783             117
# ..                  ...             ...             ...             ...
# 925              Others            1688            1649              39
# 926           Australia           13148           12929             219
# 927         New Zealand            1764            1734              30
# 928              Others              35              31               4
# 929  Unspecified places               7               7               0
#
#     Continent Region Continent  Year
# 0             Africa    Africa  2006
# ...

# %%
reset1=reset.drop_duplicates(subset=['Place','Year'])
reset1
# Out:
#                   Place  Total Tourists  Tourist by Air  Tourist by Sea  \
# 0          South Africa            3545            3012             533
# 1                Angola           21662           21606              56
# 2            Cape Green            2407            2407               0
# 3               Nigeria             238             233               5
# 4                Others            1900            1783             117
# ..                  ...             ...             ...             ...
# 923              Turkey            1312            1197             115
# 924             Ukraine            2103            2038              65
# 926           Australia           13148           12929             219
# 927         New Zealand            1764            1734              30
# 929  Unspecified places               7               7               0
#
#     Continent Region Continent  Year
# 0             Africa    Africa  2006
# ...

# %%
reset1.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
sns.pairplot(
    reset1,kind="hist")

# %%
sns.pairplot(reset1, height=1.5)

# %%
df1
# Out:
#                 Total Tourists  Tourist by Air  Tourist by Sea  \
# Continent Code
# 3                         3545            3012             533
# 3                        21662           21606              56
# 3                         2407            2407               0
# 3                          238             233               5
# 3                         1900            1783             117
# ...                        ...             ...             ...
# 5                         1688            1649              39
# 4                        13148           12929             219
# 4                         1764            1734              30
# 4                           35              31               4
# 4                            7               7               0
#
#                Continent Region Continent  Year
# Continent Code
# 3                        Africa    Africa  2006
# 3                        Africa    Africa  2006
# ...

# %%
df2=df1.copy()
 
df2.query('Continent == "Europe"') [['Tourist by Air','Tourist by Sea','Total Tourists']]
# Out:
#              Tourist by Air  Tourist by Sea  Total Tourists
# Place
#    Germany            51520            2169           53689
#  Austria               2839             303            3142
#    Belgium             8070             129            8199
#     Denmark            6360             300            6660
#    Spain              31241             495           31736
# ...                     ...             ...             ...
# Switzerland            7817              81            7898
# Switzerland           13085             159           13244
# Turkey                 1197             115            1312
# Ukraine                2038              65            2103
# Others                 1649              39            1688
#
# [340 rows x 3 columns]

# %%
dfE= df2.query('Continent == "Europe"') [['Tourist by Air','Tourist by Sea','Total Tourists']]

boxplot = dfE.boxplot(column=['Tourist by Air','Tourist by Sea'],grid=False, rot=45, fontsize=15)

# %%
#import pandas as pd
#index = pd.Index(range(1, 341, 1))
#dfE = dfE.set_index(index, append=True)
#dfE
# Out:
#                      Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
#    Germany  1   1             51520            2169           53689
#  Austria    2   2              2839             303            3142
#    Belgium  3   3              8070             129            8199
#     Denmark 4   4              6360             300            6660
#    Spain    5   5             31241             495           31736
# ...                             ...             ...             ...
# Switzerland 336 336            7817              81            7898
#             337 337           13085             159           13244
# Turkey      338 338            1197             115            1312
# Ukraine     339 339            2038              65            2103
# Others      340 340            1649              39            1688
#
#                      MAX Tourists Europe
# Place
#    Germany  1   1                  53689
#  Austria    2   2                   3142
# ...

# %%
import numpy as np
dfE["MAX Tourists Europe"] = dfE.max(axis=1)
r=dfE.reset_index(level='Place')
r
# Out:
#            Place  Tourist by Air  Tourist by Sea  Total Tourists  \
# 0        Germany           51520            2169           53689
# 1        Austria            2839             303            3142
# 2        Belgium            8070             129            8199
# 3        Denmark            6360             300            6660
# 4          Spain           31241             495           31736
# ..           ...             ...             ...             ...
# 335  Switzerland            7817              81            7898
# 336  Switzerland           13085             159           13244
# 337       Turkey            1197             115            1312
# 338      Ukraine            2038              65            2103
# 339       Others            1649              39            1688
#
#      MAX Tourists Europe
# 0                  53689
# 1                   3142
# 2                   8199
# 3                   6660
# 4                  31736
# ..                   ...
# ...

# %%
for i in range(100,3000):
    if dfE.iloc[i]['Turkey']== True:
         print(dfE.iloc[i]['Turkey'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Turkey'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfE.plot.kde(bw_method=0.3)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfE.plot.kde(bw_method=5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfA= df2.query('Continent == "Asia"') [['Tourist by Air','Tourist by Sea','Total Tourists']]
dfA
dfA["MAX Tourists Asia"] = dfA.max(axis=1)
dfA
dfA.reset_index(level='Place')
# Out:
#                  Place  Tourist by Air  Tourist by Sea  Total Tourists  \
# 0                China            6833              53            6886
# 1                Japan            4425             161            4586
# 2          south korea            2106             175            2281
# 3               Others            4761            2886            7647
# 4         Saudi Arabia              81               0              81
# ..                 ...             ...             ...             ...
# 134  Republic of Korea            4273              18            4291
# 135              Syria             103               0             103
# 136           Thailand             669               8             677
# 137             Taiwan             741             111             852
# 138             Others            2182              21            2203
#
#      MAX Tourists Asia
# 0                 6886
# 1                 4586
# 2                 2281
# ...

# %%
boxplot = dfA.boxplot(column=['Tourist by Air','Tourist by Sea'],grid=False, rot=45, fontsize=15)

# %%
dfAM= df2.query('Continent == "America"') [['Tourist by Air','Tourist by Sea','Total Tourists']]
dfAM["MAX Tourists America"] = dfAM.max(axis=1)
dfAM
dfAM.reset_index(level='Place')
# Out:
#              Place  Tourist by Air  Tourist by Sea  Total Tourists  \
# 0       Costa Rica             600              13             613
# 1           Panama             293              21             314
# 2       Porto Rico             290              55             345
# 3           Others            2363             828            3191
# 4           Canada           13828            1477           15305
# ..             ...             ...             ...             ...
# 298       Paraguay            4357             117            4474
# 299           Peru           25150              83           25233
# 300       Suriname              16               0              16
# 301        Uruguai           33106            4211           37317
# 302      Venezuela            6965              84            7049
#
#      MAX Tourists America
# 0                     613
# 1                     314
# 2                     345
# 3                    3191
# ...

# %%
boxplot = dfAM.boxplot(column=['Tourist by Air','Tourist by Sea'],grid=False, rot=45, fontsize=15)

# %%
ax = dfAM.plot.bar(x='Tourist by Sea',y='MAX Tourists',rot=0,stacked=True)

# %%
ax = dfAM.plot(x='Tourist by Air', y='Tourist by Sea')
dfA.plot(ax=ax, x='Tourist by Air', y='Tourist by Sea')
# Out:
# <AxesSubplot:xlabel='Tourist by Air'>

# %%
df2.query("Year==2019")
# Out:
#                     Total Tourists  Tourist by Air  Tourist by Sea  \
# Place
#  South Africa                 3241            3129             112
# Angola                        2440            2440               0
# Cape Green                      73              73               0
# Egypt                          583             579               4
# Gana                            65              65               0
# ...                            ...             ...             ...
# Others                        1688            1649              39
# Australia                    13148           12929             219
#  New Zealand                  1764            1734              30
# Others                          35              31               4
# Unspecified places               7               7               0
#
#                    Continent Region Continent  Year
# Place
#  South Africa                Africa    Africa  2019
# ...

# %%
df2.Continent.describe()
# Out:
# count        930
# unique         5
# top       Europe
# freq         340
# Name: Continent, dtype: object

# %%
dfAF= df2.query('Continent == "Africa"') [['Tourist by Air','Tourist by Sea','Total Tourists']]
dfAF["MAX Tourists Africa"] = dfAF.max(axis=1)
dfAF
dfAF.reset_index(level='Place')
dfAF
# Out:
#                   Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
#     South Africa            3012             533            3545
#    Angola                  21606              56           21662
#    Cape Green               2407               0            2407
#    Nigeria                   233               5             238
# Others                      1783             117            1900
# ...                          ...             ...             ...
# Mozambique                  1011               4            1015
# Nigeria                      313               0             313
# Kenya                         92              11             103
# Tunasia                      802               3             805
# Others                      1151              11            1162
#
#                   MAX Tourists Africa
# Place
#     South Africa                 3545
#    Angola                       21662
#    Cape Green                    2407
# ...

# %%
dfAF.loc[['Others']]
# Out:
#         Tourist by Air  Tourist by Sea  Total Tourists  MAX Tourists Africa
# Place
# Others            1783             117            1900                 1900
# Others            1834             100            1934                 1934
# Others            1577               2            1579                 1579
# Others            2494              11            2505                 2505
# Others            3332             266            3598                 3598
# Others            3868              35            3903                 3903
# Others            6619               8            6627                 6627
# Others            6092              35            6127                 6127
# Others            9205              16            9221                 9221
# Others            4770               8            4778                 4778
# Others            2628               4            2632                 2632
# ...

# %%
dfO= df2.query('Continent == "Oceania"') [['Tourist by Air','Tourist by Sea','Total Tourists']]
dfO["MAX Tourists Oceania"] = dfO.max(axis=1)
dfO
dfO.reset_index(level='Place')
dfO
# Out:
#                     Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
#    Australia                  6380             453            6833
#   New Zealand                 1327             121            1448
# Australia                     7939             381            8320
#  New Zealand                  2052              94            2146
# Others                          48               0               0
# Unspecified places             171              99             270
# Australia                     9604             419           10023
#  New Zealand                  2020              75            2095
# Others                          48               0              48
# Unspecified places              80              10              90
# Australia                    12173             329           12502
#  New Zealand                  2868              31            2899
# Others                          27               1              28
# ...

# %%
#Others=df[dfO['Place']=="Australia"]
##a=dfO[dfO['Place'] == "Australia"]
#print(dfO.loc[dfO['Place'] == 'Australia'])
# Using the operator .loc[]
# to select multiple rows
result = dfO.loc[['Australia']]
  
# Show the dataframe
result
# Out:
#            Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
# Australia            7939             381            8320
# Australia            9604             419           10023
# Australia           12173             329           12502
# Australia           10943             411           11354
# Australia           10960             452           11412
# Australia           15843             130           15973
# Australia           16492             285           16777
# Australia           27477             201           27678
# Australia           14373             189           14562
# Australia           18465             218           18683
# Australia           11292            1659           12951
# Australia           11041             315           11356
# Australia           12929             219           13148
#
#            MAX Tourists Oceania
# Place
# Australia                  8320
# Australia                 10023
# Australia                 12502
# ...

# %%
dfO.loc[['Others']]
# Out:
#         Tourist by Air  Tourist by Sea  Total Tourists  MAX Tourists Oceania
# Place
# Others              48               0               0                    48
# Others              48               0              48                    48
# Others              27               1              28                    28
# Others              69              54             123                   123
# Others              22               1              23                    23
# Others             152               1             153                   153
# Others              52               5              57                    57
# Others              40               0              40                    40
# Others              37               1              38                    38
# Others             366               2             368                   368
# Others              11               0              11                    11
# ...

# %%
dO=dfO.copy()
dO
# Out:
#                     Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
#    Australia                  6380             453            6833
#   New Zealand                 1327             121            1448
# Australia                     7939             381            8320
#  New Zealand                  2052              94            2146
# Others                          48               0               0
# Unspecified places             171              99             270
# Australia                     9604             419           10023
#  New Zealand                  2020              75            2095
# Others                          48               0              48
# Unspecified places              80              10              90
# Australia                    12173             329           12502
#  New Zealand                  2868              31            2899
# Others                          27               1              28
# ...

# %%
dO.drop(dO[(dO['Tourist by Air'] <10) & (dO['Total Tourists'] < 10)].index, inplace=True)

dO
# Out:
#                Tourist by Air  Tourist by Sea  Total Tourists  \
# Place
#    Australia             6380             453            6833
#   New Zealand            1327             121            1448
# Australia                7939             381            8320
#  New Zealand             2052              94            2146
# Others                     48               0               0
# Australia                9604             419           10023
#  New Zealand             2020              75            2095
# Others                     48               0              48
# Australia               12173             329           12502
#  New Zealand             2868              31            2899
# Others                     27               1              28
# Australia               10943             411           11354
#  New Zealand             2676              51            2727
# Others                     69              54             123
# ...

# %%
#dO.drop(dO.loc[['Others']])

#dO
s=dO.reset_index(level='Place')
s
##dO = dO.set_index('Place', append=True)
#dO
# Out:
#             Place  Tourist by Air  Tourist by Sea  Total Tourists  \
# 0       Australia            6380             453            6833
# 1     New Zealand            1327             121            1448
# 2       Australia            7939             381            8320
# 3     New Zealand            2052              94            2146
# 4          Others              48               0               0
# 5       Australia            9604             419           10023
# 6     New Zealand            2020              75            2095
# 7          Others              48               0              48
# 8       Australia           12173             329           12502
# 9     New Zealand            2868              31            2899
# 10         Others              27               1              28
# 11      Australia           10943             411           11354
# 12    New Zealand            2676              51            2727
# ...

# %%
Or=dO.loc[['Others']]

dO.drop(Or)
dO
